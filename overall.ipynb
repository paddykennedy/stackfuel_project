# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.formula.api as smf
# %matplotlib inline
import matplotlib.pyplot as plt
import sqlalchemy as sa

# %%
df = pd.read_csv('tipsst10_tabular.tsv',sep='\t',na_values = ':')
df.head()
# Out:
#   freq,sectperf,unit,geo\TIME_PERIOD      1995       1996       1997   \
# 0                 A,TOTAL,MIO_NAC,AT  2701.68 e  2885.55 e  3123.21 e
# 1                 A,TOTAL,MIO_NAC,BE   3467.36    3734.99     4055.6
# 2                 A,TOTAL,MIO_NAC,BG     5.447     9.148 b    88.591
# 3                 A,TOTAL,MIO_NAC,CY         :          :          :
# 4                 A,TOTAL,MIO_NAC,CZ  13982.6 b   16264.3    19477.4
#
#        1998       1999       2000       2001       2002        2003   ...  \
# 0  3399.835    3761.8 e  4028.67 e  4393.09 e  4684.313    5041.98 e  ...
# 1   4276.21   4617.525    4963.95   5373.378   5200.737    5177.444   ...
# 2   127.598    134.45 b   139.265    138.539    158.327      173.01   ...
# 3    18.419     21.221      24.04     27.051     33.217      40.892   ...
# 4     22865    23646.7    26487.2      28337    29552.2   32246.596   ...
#
#         2012        2013        2014        2015        2016        2017   \
# ...

# %%
import re
new_columns = df['freq,sectperf,unit,geo\\TIME_PERIOD'].str.split(',', expand=True)

new_columns.columns = ['freq', 'sectperf','unit', 'geo']
df = pd.concat([df, new_columns], axis=1)
print(df.head())

for i in range(1,28):
    df.iloc[:,i] = df.iloc[:,i].apply(lambda x: re.sub(r'[^0-9.]', '', x))
df

for i in range(1,28):
    df.iloc[:,i] = pd.to_numeric(df.iloc[:,i], errors='coerce')
df
# Out:
#   freq,sectperf,unit,geo\TIME_PERIOD      1995       1996       1997   \
# 0                 A,TOTAL,MIO_NAC,AT  2701.68 e  2885.55 e  3123.21 e
# 1                 A,TOTAL,MIO_NAC,BE   3467.36    3734.99     4055.6
# 2                 A,TOTAL,MIO_NAC,BG     5.447     9.148 b    88.591
# 3                 A,TOTAL,MIO_NAC,CY         :          :          :
# 4                 A,TOTAL,MIO_NAC,CZ  13982.6 b   16264.3    19477.4
#
#        1998       1999       2000       2001       2002        2003   ...  \
# 0  3399.835    3761.8 e  4028.67 e  4393.09 e  4684.313    5041.98 e  ...
# 1   4276.21   4617.525    4963.95   5373.378   5200.737    5177.444   ...
# 2   127.598    134.45 b   139.265    138.539    158.327      173.01   ...
# 3    18.419     21.221      24.04     27.051     33.217      40.892   ...
# 4     22865    23646.7    26487.2      28337    29552.2   32246.596   ...
#
#         2016        2017        2018         2019         2020          2021   \
# ...

# %%
import re
for i in range(1,20):
    df.iloc[:,i] = df.iloc[:,i].apply(lambda x: re.sub(r'[^0-9.]', '', x))
df

for i in range(1,20):
    df.iloc[:,i] = pd.to_numeric(df.iloc[:,i], errors='coerce')
df
